# %% [markdown]
# ## Pandas analysis
#
# This exercise consists in analyzing a dataset containg timing information from a series of Time-to-Digital-Converters (TDC) implemented in a couple of FPGAs. Each measurement (i.e. each row of the input file) consists of a flag that specifies the type of message ('HEAD', which in this case is always 1), two addresses of the TDC providing the signal ('FPGA' and 'TDC_CHANNEL'), and the timing information ('ORBIT_CNT', 'BX_COUNTER', and 'TDC_MEAS'). Each TDC count corresponds to 25/30 ns, whereas a unit of BX_COUNTER corresponds to 25 ns, and the ORBIT_CNT is increased every 'x' BX_COUNTER. This allows to store the time in a similar way to hours, minutes and seconds.

# %%
# If you didn't download it yet, please get the relevant file now!
# !wget https://www.dropbox.com/s/xvjzaxzz3ysphme/data_000637.txt -P ~/data/
# Out:
# --2024-11-28 08:35:27--  https://www.dropbox.com/s/xvjzaxzz3ysphme/data_000637.txt
# Resolving www.dropbox.com (www.dropbox.com)... failed: Temporary failure in name resolution.
# wget: unable to resolve host address ‘www.dropbox.com’

# %% [markdown]
# 1\. Create a Pandas DataFrame reading N rows of the 'data_000637.txt' dataset. Choose N to be smaller than or equal to the maximum number of rows and larger that 10k.
#
# 2\. Find out the number of BX in a ORBIT (the value 'x').
#
# 3\. Find out how much the data taking lasted. You can either make an estimate based on the fraction of the measurements (rows) you read, or perform this check precisely by reading out the whole dataset.
#
# 4\. Create a new column with the absolute time in ns (as a combination of the other three columns with timing information).
#
# 5\. Replace the values (all 1) of the HEAD column randomly with 0 or 1.
#
# 6\. Create a new DataFrame that contains only the rows with HEAD=1.
#
# 7\. Make two occupancy plots (one for each FPGA), i.e. plot the number of counts per TDC channel
#
# 8\. Use the groupby method to find out the noisy channels, i.e. the TDC channels with most counts (say the top 3)
#
# 9\. Count the number of unique orbits. Count the number of unique orbits with at least one measurement from TDC_CHANNEL=139

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("~/data/data_000637.txt")
df[0:500]
df[0:15000]
# Out:
#        HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS
# 0         1     0          123  3869200167        2374        26
# 1         1     0          124  3869200167        2374        27
# 2         1     0           63  3869200167        2553        28
# 3         1     0           64  3869200167        2558        19
# 4         1     0           64  3869200167        2760        25
# ...     ...   ...          ...         ...         ...       ...
# 14995     1     1            4  3869200316        3399         9
# 14996     1     1           17  3869200316        3400        15
# 14997     1     1           10  3869200316        3530        16
# 14998     1     1            8  3869200316        3533        18
# 14999     1     0          139  3869200316        3539         0
#
# [15000 rows x 6 columns]

# %%
#2.
#df2 = df.iloc[:,3:5]
df2 = df2[df2["BX_COUNTER"] == np.max(df["BX_COUNTER"])]
BC_unit = np.max(df["BX_COUNTER"]) + 1

# %%
#3.
df2 = df[df["ORBIT_CNT"] == np.max(df["ORBIT_CNT"])]
df2 = df2[df2["BX_COUNTER"] == np.max(df2["BX_COUNTER"])]
time_max = (df2["TDC_MEAS"][1310718] * (25/30) + 25*df2["BX_COUNTER"][1310718] + df2["ORBIT_CNT"][1310718] * BC_unit * 25)
print(df2)

df2 = df[df["ORBIT_CNT"] == np.min(df["ORBIT_CNT"])]
df2 = df2[df2["BX_COUNTER"] == np.min(df2["BX_COUNTER"])]
time_min = (df2["TDC_MEAS"][0] * (25/30) + 25*df2["BX_COUNTER"][0] + df2["ORBIT_CNT"][0] * BC_unit * 25)
print(df2)

acq_time = time_max - time_min
print("total acquisition time (ns) = ", acq_time)
# Out:
#          HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS
# 1310718     1     0          139  3869211171         769         0
#    HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS
# 0     1     0          123  3869200167        2374        26
# 1     1     0          124  3869200167        2374        27
# total acquisition time (ns) =  980416253.3125

# %%
#4.
df["time_converted"] = (df["TDC_MEAS"] * (25/30) + 25*df["BX_COUNTER"] + df["ORBIT_CNT"] * BC_unit * 25)
df
# Out:
#          HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS  \
# 0           1     0          123  3869200167        2374        26
# 1           1     0          124  3869200167        2374        27
# 2           1     0           63  3869200167        2553        28
# 3           1     0           64  3869200167        2558        19
# 4           1     0           64  3869200167        2760        25
# ...       ...   ...          ...         ...         ...       ...
# 1310715     1     0           62  3869211171         762        14
# 1310716     1     1            4  3869211171         763        11
# 1310717     1     0           64  3869211171         764         0
# 1310718     1     0          139  3869211171         769         0
# 1310719     1     0           61  3869211171         762        18
#
#          time_converted
# 0          3.447457e+14
# 1          3.447457e+14
# 2          3.447457e+14
# 3          3.447457e+14
# 4          3.447457e+14
# ...

# %%
#5
df["HEAD"] = np.random.randint(0,2,len(df))
df
# Out:
#          HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS  \
# 0           0     0          123  3869200167        2374        26
# 1           1     0          124  3869200167        2374        27
# 2           0     0           63  3869200167        2553        28
# 3           1     0           64  3869200167        2558        19
# 4           1     0           64  3869200167        2760        25
# ...       ...   ...          ...         ...         ...       ...
# 1310715     0     0           62  3869211171         762        14
# 1310716     0     1            4  3869211171         763        11
# 1310717     1     0           64  3869211171         764         0
# 1310718     0     0          139  3869211171         769         0
# 1310719     0     0           61  3869211171         762        18
#
#          time_converted
# 0          3.447457e+14
# 1          3.447457e+14
# 2          3.447457e+14
# 3          3.447457e+14
# 4          3.447457e+14
# ...

# %%
#6
new_df = df[df["HEAD"] == 1]
new_df
# Out:
#          HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS  \
# 1           1     0          124  3869200167        2374        27
# 3           1     0           64  3869200167        2558        19
# 4           1     0           64  3869200167        2760        25
# 5           1     0           63  3869200167        2762         4
# 6           1     0           61  3869200167        2772        14
# ...       ...   ...          ...         ...         ...       ...
# 1310693     1     0           58  3869211170        3521        14
# 1310695     1     1            2  3869211170        3527        24
# 1310709     1     1           38  3869211171         417         8
# 1310710     1     1           36  3869211171         427        13
# 1310717     1     0           64  3869211171         764         0
#
#          time_converted
# 1          3.447457e+14
# 3          3.447457e+14
# 4          3.447457e+14
# 5          3.447457e+14
# 6          3.447457e+14
# ...

# %%
#7
import matplotlib.pyplot as plt
plt.figure()
plt.title("FPGA 0")
plt.hist(df["TDC_CHANNEL"][df["FPGA"]==0])
plt.show()

plt.figure()
plt.title("FPGA 1")
plt.hist(df["TDC_CHANNEL"][df["FPGA"]==1])
plt.show()

# %%
#8
df2 = df.iloc[:, :3]
df2 = df2.drop(["FPGA"], axis = 1)
df2
search = df2.groupby("TDC_CHANNEL").sum().sort_values(by="HEAD")
print("Most noisy channels", "\n",search.tail(3))
# Out:
# Most noisy channels
#                 HEAD
# TDC_CHANNEL
# 63            64642
# 64            66020
# 139          108059

# %%
#9a Count the number of unique orbits.
unique_orbits = df["ORBIT_CNT"].unique()
#9b Count the number of unique orbits with at least one measurement from TDC_CHANNEL=139
unique_orbits_139 = df[df["TDC_CHANNEL"] == 139]["ORBIT_CNT"].unique()

unique_df1 = pd.DataFrame({"ORBIT_CNT" : unique_orbits})
unique_df2 = pd.DataFrame({"ORBIT_CNT" : unique_orbits_139, "has_139" : 1})

result = pd.merge(unique_df1,unique_df2, on = "ORBIT_CNT" ,how = "left").fillna(0).astype(int)

print(result)
#easier:
"""
#9a Count the number of unique orbits.
unique_orbits = df["ORBIT_CNT"].nunique()
#9b Count the number of unique orbits with at least one measurement from TDC_CHANNEL=139
unique_orbits_139 = df[df["TDC_CHANNEL"] == 139]["ORBIT_CNT"].nunique()
"""
# Out:
#         ORBIT_CNT  has_139
# 0      3869200167        1
# 1      3869200168        1
# 2      3869200169        1
# 3      3869200170        1
# 4      3869200171        1
# ...           ...      ...
# 10996  3869211167        1
# 10997  3869211168        1
# 10998  3869211169        1
# 10999  3869211170        1
# 11000  3869211171        1
#
# [11001 rows x 2 columns]
